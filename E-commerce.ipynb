# %%
import pandas as pd
import os
from sqlalchemy import create_engine, text

# %%
host = "localhost"
user = "root"
password = "LenovoIdeapad"
database = "premior_db"

# %%
engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}"
)

# %%
with engine.connect() as conn:
    conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {database}"))
    conn.commit()

print(f"Database '{database}' created successfully.")
# Out:
# Database 'premior_db' created successfully.

# %%
engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}/{database}"
)

# %%
folder_path = r"D:\Projects\Premior Internship"

# %%
csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]

print(csv_files)
# Out:
# ['Cleaned_dataset.csv']

# %%
for file in csv_files:

    file_path = os.path.join(folder_path, file)

    table_name = os.path.splitext(file)[0].lower()

    print(f"Uploading {table_name}...")

    df = pd.read_csv(file_path)

    df.to_sql(
        name=table_name,
        con=engine,
        if_exists="replace",
        index=False,
        chunksize=1000,
        method="multi"
    )

    print(f"{table_name} uploaded successfully.")
# Out:
# Uploading cleaned_dataset...
# cleaned_dataset uploaded successfully.

# %%
query = "SHOW TABLES"

tables = pd.read_sql(query, engine)

tables
# Out:
#   Tables_in_premior_db
# 0      cleaned_dataset

# %%
for file in csv_files:

    file_path = os.path.join(folder_path, file)

    df = pd.read_csv(file_path)

    print(f"{file} : {df.shape}")
# Out:
# Cleaned_dataset.csv : (51271, 21)

# %%
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name  sales  quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue  408.0       2.0
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed  120.0       3.0
# 2  Office Supplies      Storage      Tenex Box, Single Width   66.0       4.0
# 3  Office Supplies        Paper  Enermax Note Cards, Premium   45.0       3.0
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack  114.0       5.0
#
#    discount  profit  shipping_cost  order_priority  year
# 0       0.0  106.14          35.46          Medium  2011
# 1       0.1   36.04           9.72          Medium  2011
# 2       0.0   29.64           8.17            High  2011
# 3       0.5  -26.06           4.82            High  2011
# 4       0.1   37.77           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %%
df.tail(5)
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 51266  CA-2014-115427  31-12-2014  04-01-2015  Standard Class
# 51267    MO-2014-2560  31-12-2014  05-01-2015  Standard Class
# 51268  MX-2014-110527  31-12-2014  02-01-2015    Second Class
# 51269  MX-2014-114783  31-12-2014  06-01-2015  Standard Class
# 51270  CA-2014-156720  31-12-2014  04-01-2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 51266        Erica Bern  Corporate        California  United States      US
# 51267         Liz Preis   Consumer  Souss-Massa-Draâ        Morocco  Africa
# 51268  Charlotte Melton   Consumer           Managua      Nicaragua   LATAM
# 51269     Tamara Dahlen   Consumer         Chihuahua         Mexico   LATAM
# 51270     Jill Matthias   Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 51266     West  ...  Office Supplies      Binders
# 51267   Africa  ...  Office Supplies      Binders
# 51268  Central  ...  Office Supplies       Labels
# 51269    North  ...  Office Supplies       Labels
# 51270     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales  quantity  \
# 51266  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl  14.0       2.0
# 51267          Wilson Jones Hole Reinforcements, Clear   4.0       1.0
# 51268           Hon Color Coded Labels, 5000 Label Set  26.0       3.0
# 51269           Hon Legal Exhibit Labels, Alphabetical   7.0       1.0
# 51270                              Bagged Rubber Bands   3.0       3.0
#
#        discount  profit  shipping_cost  order_priority  year
# 51266       0.2    4.52           0.89          Medium  2014
# 51267       0.0    0.42           0.49          Medium  2014
# 51268       0.0   12.36           0.35          Medium  2014
# 51269       0.0    0.56           0.20          Medium  2014
# 51270       0.2   -0.60           0.17          Medium  2014
#
# [5 rows x 21 columns]

# %%
df.
